# %%
import keras
from keras.models import Model
from keras.applications.inception_v3 import InceptionV3
from keras.layers import Dense, GlobalAveragePooling2D, Input
import tensorflow as tf
import coremltools
from keras.models import load_model

input_tensor = Input(shape=(224, 224, 3))
base_model = InceptionV3(input_tensor=input_tensor, weights='imagenet', include_top=False)
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(50, activation='relu')(x)
# x = Dropout(0.5)(x)
x = Dense(50, activation='relu')(x)
# x = Dropout(0.5)(x)
output_dim = 2
predictions = Dense(output_dim, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=predictions)
model.load_weights('inception_v3_50_50_13_best_f1.h5')

core_ml=coremltools.converters.keras.convert(model)
core_ml.save('coreml_model.mlmodel')
# Out:
# /Users/turbo_strong/Desktop/KaggleDiatetic/coreML/lib/python2.7/site-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# 0 : input_4, <keras.engine.input_layer.InputLayer object at 0x158c10fd0>
# 1 : conv2d_189, <keras.layers.convolutional.Conv2D object at 0x158d90dd0>
# 2 : batch_normalization_189, <keras.layers.normalization.BatchNormalization object at 0x158d7ead0>
# 3 : activation_189, <keras.layers.core.Activation object at 0x158d7ec50>
# 4 : conv2d_190, <keras.layers.convolutional.Conv2D object at 0x158d7ecd0>
# 5 : batch_normalization_190, <keras.layers.normalization.BatchNormalization object at 0x158d7eed0>
# 6 : activation_190, <keras.layers.core.Activation object at 0x158d7ef10>
# 7 : conv2d_191, <keras.layers.convolutional.Conv2D object at 0x1533c9090>
# 8 : batch_normalization_191, <keras.layers.normalization.BatchNormalization object at 0x1533c9190>
# 9 : activation_191, <keras.layers.core.Activation object at 0x1533c91d0>
# 10 : max_pooling2d_9, <keras.layers.pooling.MaxPooling2D object at 0x1533c9310>
# 11 : conv2d_192, <keras.layers.convolutional.Conv2D object at 0x1533c9390>
# 12 : batch_normalization_192, <keras.layers.normalization.BatchNormalization object at 0x1533c9490>
# 13 : activation_192, <keras.layers.core.Activation object at 0x1533c94d0>
# 14 : conv2d_193, <keras.layers.convolutional.Conv2D object at 0x1533c9610>
# 15 : batch_normalization_193, <keras.layers.normalization.BatchNormalization object at 0x1533c9710>
# 16 : activation_193, <keras.layers.core.Activation object at 0x1533c9750>
# 17 : max_pooling2d_10, <keras.layers.pooling.MaxPooling2D object at 0x1533c9890>
# 18 : conv2d_197, <keras.layers.convolutional.Conv2D object at 0x1533c9910>
# 19 : batch_normalization_197, <keras.layers.normalization.BatchNormalization object at 0x1533c9a10>
# 20 : activation_197, <keras.layers.core.Activation object at 0x1533c9a50>
# 21 : conv2d_195, <keras.layers.convolutional.Conv2D object at 0x1533c9b90>
# 22 : conv2d_198, <keras.layers.convolutional.Conv2D object at 0x1533c9c90>
# 23 : batch_normalization_195, <keras.layers.normalization.BatchNormalization object at 0x1533c9d90>
# 24 : batch_normalization_198, <keras.layers.normalization.BatchNormalization object at 0x1533c9dd0>
# 25 : activation_195, <keras.layers.core.Activation object at 0x1533c9f10>
# 26 : activation_198, <keras.layers.core.Activation object at 0x1533d0090>
# 27 : average_pooling2d_19, <keras.layers.pooling.AveragePooling2D object at 0x1533d00d0>
# 28 : conv2d_194, <keras.layers.convolutional.Conv2D object at 0x1533d0150>
# 29 : conv2d_196, <keras.layers.convolutional.Conv2D object at 0x1533d0250>
# 30 : conv2d_199, <keras.layers.convolutional.Conv2D object at 0x1533d0350>
# 31 : conv2d_200, <keras.layers.convolutional.Conv2D object at 0x1533d0450>
# 32 : batch_normalization_194, <keras.layers.normalization.BatchNormalization object at 0x1533d0550>
# 33 : batch_normalization_196, <keras.layers.normalization.BatchNormalization object at 0x1533d0590>
# 34 : batch_normalization_199, <keras.layers.normalization.BatchNormalization object at 0x1533d06d0>
# 35 : batch_normalization_200, <keras.layers.normalization.BatchNormalization object at 0x1533d0810>
# 36 : activation_194, <keras.layers.core.Activation object at 0x1533d0950>
# 37 : activation_196, <keras.layers.core.Activation object at 0x1533d0a90>
# 38 : activation_199, <keras.layers.core.Activation object at 0x1533d0ad0>
# 39 : activation_200, <keras.layers.core.Activation object at 0x1533d0b10>
# 40 : mixed0, <keras.layers.merge.Concatenate object at 0x1533d0b50>
# 41 : conv2d_204, <keras.layers.convolutional.Conv2D object at 0x1533d0b90>
# 42 : batch_normalization_204, <keras.layers.normalization.BatchNormalization object at 0x1533d0c90>
# 43 : activation_204, <keras.layers.core.Activation object at 0x1533d0cd0>
# 44 : conv2d_202, <keras.layers.convolutional.Conv2D object at 0x1533d0e10>
# 45 : conv2d_205, <keras.layers.convolutional.Conv2D object at 0x1533d0f10>
# 46 : batch_normalization_202, <keras.layers.normalization.BatchNormalization object at 0x1533da050>
# 47 : batch_normalization_205, <keras.layers.normalization.BatchNormalization object at 0x1533da090>
# 48 : activation_202, <keras.layers.core.Activation object at 0x1533da1d0>
# 49 : activation_205, <keras.layers.core.Activation object at 0x1533da310>
# 50 : average_pooling2d_20, <keras.layers.pooling.AveragePooling2D object at 0x1533da350>
# 51 : conv2d_201, <keras.layers.convolutional.Conv2D object at 0x1533da3d0>
# 52 : conv2d_203, <keras.layers.convolutional.Conv2D object at 0x1533da4d0>
# 53 : conv2d_206, <keras.layers.convolutional.Conv2D object at 0x1533da5d0>
# 54 : conv2d_207, <keras.layers.convolutional.Conv2D object at 0x1533da6d0>
# 55 : batch_normalization_201, <keras.layers.normalization.BatchNormalization object at 0x1533da7d0>
# 56 : batch_normalization_203, <keras.layers.normalization.BatchNormalization object at 0x1533da810>
# 57 : batch_normalization_206, <keras.layers.normalization.BatchNormalization object at 0x1533da950>
# 58 : batch_normalization_207, <keras.layers.normalization.BatchNormalization object at 0x1533daa90>
# 59 : activation_201, <keras.layers.core.Activation object at 0x1533dabd0>
# 60 : activation_203, <keras.layers.core.Activation object at 0x1533dad10>
# 61 : activation_206, <keras.layers.core.Activation object at 0x1533dad50>
# 62 : activation_207, <keras.layers.core.Activation object at 0x1533dad90>
# 63 : mixed1, <keras.layers.merge.Concatenate object at 0x1533dadd0>
# 64 : conv2d_211, <keras.layers.convolutional.Conv2D object at 0x1533dae10>
# 65 : batch_normalization_211, <keras.layers.normalization.BatchNormalization object at 0x1533daf10>
# 66 : activation_211, <keras.layers.core.Activation object at 0x1533daf50>
# 67 : conv2d_209, <keras.layers.convolutional.Conv2D object at 0x1533e30d0>
# 68 : conv2d_212, <keras.layers.convolutional.Conv2D object at 0x1533e31d0>
# 69 : batch_normalization_209, <keras.layers.normalization.BatchNormalization object at 0x1533e32d0>
# 70 : batch_normalization_212, <keras.layers.normalization.BatchNormalization object at 0x1533e3310>
# 71 : activation_209, <keras.layers.core.Activation object at 0x1533e3450>
# 72 : activation_212, <keras.layers.core.Activation object at 0x1533e3590>
# 73 : average_pooling2d_21, <keras.layers.pooling.AveragePooling2D object at 0x1533e35d0>
# 74 : conv2d_208, <keras.layers.convolutional.Conv2D object at 0x1533e3650>
# 75 : conv2d_210, <keras.layers.convolutional.Conv2D object at 0x1533e3750>
# 76 : conv2d_213, <keras.layers.convolutional.Conv2D object at 0x1533e3850>
# 77 : conv2d_214, <keras.layers.convolutional.Conv2D object at 0x1533e3950>
# 78 : batch_normalization_208, <keras.layers.normalization.BatchNormalization object at 0x1533e3a50>
# 79 : batch_normalization_210, <keras.layers.normalization.BatchNormalization object at 0x1533e3a90>
# 80 : batch_normalization_213, <keras.layers.normalization.BatchNormalization object at 0x1533e3bd0>
# 81 : batch_normalization_214, <keras.layers.normalization.BatchNormalization object at 0x1533e3d10>
# 82 : activation_208, <keras.layers.core.Activation object at 0x1533e3e50>
# 83 : activation_210, <keras.layers.core.Activation object at 0x1533e3f90>
# 84 : activation_213, <keras.layers.core.Activation object at 0x1533e3fd0>
# 85 : activation_214, <keras.layers.core.Activation object at 0x1533eb050>
# 86 : mixed2, <keras.layers.merge.Concatenate object at 0x1533eb090>
# 87 : conv2d_216, <keras.layers.convolutional.Conv2D object at 0x1533eb0d0>
# 88 : batch_normalization_216, <keras.layers.normalization.BatchNormalization object at 0x1533eb1d0>
# 89 : activation_216, <keras.layers.core.Activation object at 0x1533eb210>
# 90 : conv2d_217, <keras.layers.convolutional.Conv2D object at 0x1533eb350>
# 91 : batch_normalization_217, <keras.layers.normalization.BatchNormalization object at 0x1533eb450>
# 92 : activation_217, <keras.layers.core.Activation object at 0x1533eb490>
# 93 : conv2d_215, <keras.layers.convolutional.Conv2D object at 0x1533eb5d0>
# 94 : conv2d_218, <keras.layers.convolutional.Conv2D object at 0x1533eb6d0>
# 95 : batch_normalization_215, <keras.layers.normalization.BatchNormalization object at 0x1533eb7d0>
# 96 : batch_normalization_218, <keras.layers.normalization.BatchNormalization object at 0x1533eb810>
# 97 : activation_215, <keras.layers.core.Activation object at 0x1533eb950>
# 98 : activation_218, <keras.layers.core.Activation object at 0x1533eba90>
# 99 : max_pooling2d_11, <keras.layers.pooling.MaxPooling2D object at 0x1533ebad0>
# 100 : mixed3, <keras.layers.merge.Concatenate object at 0x1533ebb50>
# 101 : conv2d_223, <keras.layers.convolutional.Conv2D object at 0x1533ebb90>
# 102 : batch_normalization_223, <keras.layers.normalization.BatchNormalization object at 0x1533ebc90>
# 103 : activation_223, <keras.layers.core.Activation object at 0x1533ebcd0>
# 104 : conv2d_224, <keras.layers.convolutional.Conv2D object at 0x1533ebe10>
# 105 : batch_normalization_224, <keras.layers.normalization.BatchNormalization object at 0x1533ebf10>
# 106 : activation_224, <keras.layers.core.Activation object at 0x1533ebf50>
# 107 : conv2d_220, <keras.layers.convolutional.Conv2D object at 0x1533f60d0>
# 108 : conv2d_225, <keras.layers.convolutional.Conv2D object at 0x1533f61d0>
# 109 : batch_normalization_220, <keras.layers.normalization.BatchNormalization object at 0x1533f62d0>
# 110 : batch_normalization_225, <keras.layers.normalization.BatchNormalization object at 0x1533f6310>
# 111 : activation_220, <keras.layers.core.Activation object at 0x1533f6450>
# 112 : activation_225, <keras.layers.core.Activation object at 0x1533f6590>
# 113 : conv2d_221, <keras.layers.convolutional.Conv2D object at 0x1533f65d0>
# 114 : conv2d_226, <keras.layers.convolutional.Conv2D object at 0x1533f66d0>
# 115 : batch_normalization_221, <keras.layers.normalization.BatchNormalization object at 0x1533f67d0>
# 116 : batch_normalization_226, <keras.layers.normalization.BatchNormalization object at 0x1533f6810>
# 117 : activation_221, <keras.layers.core.Activation object at 0x1533f6950>
# 118 : activation_226, <keras.layers.core.Activation object at 0x1533f6a90>
# 119 : average_pooling2d_22, <keras.layers.pooling.AveragePooling2D object at 0x1533f6ad0>
# 120 : conv2d_219, <keras.layers.convolutional.Conv2D object at 0x1533f6b50>
# 121 : conv2d_222, <keras.layers.convolutional.Conv2D object at 0x1533f6c50>
# 122 : conv2d_227, <keras.layers.convolutional.Conv2D object at 0x1533f6d50>
# 123 : conv2d_228, <keras.layers.convolutional.Conv2D object at 0x1533f6e50>
# 124 : batch_normalization_219, <keras.layers.normalization.BatchNormalization object at 0x1533f6f50>
# 125 : batch_normalization_222, <keras.layers.normalization.BatchNormalization object at 0x1533f6f90>
# 126 : batch_normalization_227, <keras.layers.normalization.BatchNormalization object at 0x1533fe110>
# 127 : batch_normalization_228, <keras.layers.normalization.BatchNormalization object at 0x1533fe250>
# 128 : activation_219, <keras.layers.core.Activation object at 0x1533fe390>
# 129 : activation_222, <keras.layers.core.Activation object at 0x1533fe4d0>
# 130 : activation_227, <keras.layers.core.Activation object at 0x1533fe510>
# 131 : activation_228, <keras.layers.core.Activation object at 0x1533fe550>
# 132 : mixed4, <keras.layers.merge.Concatenate object at 0x1533fe590>
# 133 : conv2d_233, <keras.layers.convolutional.Conv2D object at 0x1533fe5d0>
# 134 : batch_normalization_233, <keras.layers.normalization.BatchNormalization object at 0x1533fe6d0>
# 135 : activation_233, <keras.layers.core.Activation object at 0x1533fe710>
# 136 : conv2d_234, <keras.layers.convolutional.Conv2D object at 0x1533fe850>
# 137 : batch_normalization_234, <keras.layers.normalization.BatchNormalization object at 0x1533fe950>
# 138 : activation_234, <keras.layers.core.Activation object at 0x1533fe990>
# 139 : conv2d_230, <keras.layers.convolutional.Conv2D object at 0x1533fead0>
# 140 : conv2d_235, <keras.layers.convolutional.Conv2D object at 0x1533febd0>
# 141 : batch_normalization_230, <keras.layers.normalization.BatchNormalization object at 0x1533fecd0>
# 142 : batch_normalization_235, <keras.layers.normalization.BatchNormalization object at 0x1533fed10>
# 143 : activation_230, <keras.layers.core.Activation object at 0x1533fee50>
# 144 : activation_235, <keras.layers.core.Activation object at 0x1533fef90>
# 145 : conv2d_231, <keras.layers.convolutional.Conv2D object at 0x1533fefd0>
# 146 : conv2d_236, <keras.layers.convolutional.Conv2D object at 0x153408110>
# 147 : batch_normalization_231, <keras.layers.normalization.BatchNormalization object at 0x153408210>
# 148 : batch_normalization_236, <keras.layers.normalization.BatchNormalization object at 0x153408250>
# 149 : activation_231, <keras.layers.core.Activation object at 0x153408390>
# 150 : activation_236, <keras.layers.core.Activation object at 0x1534084d0>
# 151 : average_pooling2d_23, <keras.layers.pooling.AveragePooling2D object at 0x153408510>
# 152 : conv2d_229, <keras.layers.convolutional.Conv2D object at 0x153408590>
# 153 : conv2d_232, <keras.layers.convolutional.Conv2D object at 0x153408690>
# 154 : conv2d_237, <keras.layers.convolutional.Conv2D object at 0x153408790>
# 155 : conv2d_238, <keras.layers.convolutional.Conv2D object at 0x153408890>
# 156 : batch_normalization_229, <keras.layers.normalization.BatchNormalization object at 0x153408990>
# 157 : batch_normalization_232, <keras.layers.normalization.BatchNormalization object at 0x1534089d0>
# 158 : batch_normalization_237, <keras.layers.normalization.BatchNormalization object at 0x153408b10>
# 159 : batch_normalization_238, <keras.layers.normalization.BatchNormalization object at 0x153408c50>
# 160 : activation_229, <keras.layers.core.Activation object at 0x153408d90>
# 161 : activation_232, <keras.layers.core.Activation object at 0x153408ed0>
# 162 : activation_237, <keras.layers.core.Activation object at 0x153408f10>
# 163 : activation_238, <keras.layers.core.Activation object at 0x153408f50>
# 164 : mixed5, <keras.layers.merge.Concatenate object at 0x153408f90>
# 165 : conv2d_243, <keras.layers.convolutional.Conv2D object at 0x153408fd0>
# 166 : batch_normalization_243, <keras.layers.normalization.BatchNormalization object at 0x153410110>
# 167 : activation_243, <keras.layers.core.Activation object at 0x153410150>
# 168 : conv2d_244, <keras.layers.convolutional.Conv2D object at 0x153410290>
# 169 : batch_normalization_244, <keras.layers.normalization.BatchNormalization object at 0x153410390>
# 170 : activation_244, <keras.layers.core.Activation object at 0x1534103d0>
# 171 : conv2d_240, <keras.layers.convolutional.Conv2D object at 0x153410510>
# 172 : conv2d_245, <keras.layers.convolutional.Conv2D object at 0x153410610>
# 173 : batch_normalization_240, <keras.layers.normalization.BatchNormalization object at 0x153410710>
# 174 : batch_normalization_245, <keras.layers.normalization.BatchNormalization object at 0x153410750>
# 175 : activation_240, <keras.layers.core.Activation object at 0x153410890>
# 176 : activation_245, <keras.layers.core.Activation object at 0x1534109d0>
# 177 : conv2d_241, <keras.layers.convolutional.Conv2D object at 0x153410a10>
# 178 : conv2d_246, <keras.layers.convolutional.Conv2D object at 0x153410b10>
# 179 : batch_normalization_241, <keras.layers.normalization.BatchNormalization object at 0x153410c10>
# 180 : batch_normalization_246, <keras.layers.normalization.BatchNormalization object at 0x153410c50>
# 181 : activation_241, <keras.layers.core.Activation object at 0x153410d90>
# 182 : activation_246, <keras.layers.core.Activation object at 0x153410ed0>
# 183 : average_pooling2d_24, <keras.layers.pooling.AveragePooling2D object at 0x153410f10>
# 184 : conv2d_239, <keras.layers.convolutional.Conv2D object at 0x153410f90>
# 185 : conv2d_242, <keras.layers.convolutional.Conv2D object at 0x15341a0d0>
# 186 : conv2d_247, <keras.layers.convolutional.Conv2D object at 0x15341a1d0>
# 187 : conv2d_248, <keras.layers.convolutional.Conv2D object at 0x15341a2d0>
# 188 : batch_normalization_239, <keras.layers.normalization.BatchNormalization object at 0x15341a3d0>
# 189 : batch_normalization_242, <keras.layers.normalization.BatchNormalization object at 0x15341a410>
# 190 : batch_normalization_247, <keras.layers.normalization.BatchNormalization object at 0x15341a550>
# 191 : batch_normalization_248, <keras.layers.normalization.BatchNormalization object at 0x15341a690>
# 192 : activation_239, <keras.layers.core.Activation object at 0x15341a7d0>
# 193 : activation_242, <keras.layers.core.Activation object at 0x15341a910>
# 194 : activation_247, <keras.layers.core.Activation object at 0x15341a950>
# 195 : activation_248, <keras.layers.core.Activation object at 0x15341a990>
# 196 : mixed6, <keras.layers.merge.Concatenate object at 0x15341a9d0>
# 197 : conv2d_253, <keras.layers.convolutional.Conv2D object at 0x15341aa10>
# 198 : batch_normalization_253, <keras.layers.normalization.BatchNormalization object at 0x15341ab10>
# 199 : activation_253, <keras.layers.core.Activation object at 0x15341ab50>
# 200 : conv2d_254, <keras.layers.convolutional.Conv2D object at 0x15341ac90>
# 201 : batch_normalization_254, <keras.layers.normalization.BatchNormalization object at 0x15341ad90>
# 202 : activation_254, <keras.layers.core.Activation object at 0x15341add0>
# 203 : conv2d_250, <keras.layers.convolutional.Conv2D object at 0x15341af10>
# 204 : conv2d_255, <keras.layers.convolutional.Conv2D object at 0x153423050>
# 205 : batch_normalization_250, <keras.layers.normalization.BatchNormalization object at 0x153423150>
# 206 : batch_normalization_255, <keras.layers.normalization.BatchNormalization object at 0x153423190>
# 207 : activation_250, <keras.layers.core.Activation object at 0x1534232d0>
# 208 : activation_255, <keras.layers.core.Activation object at 0x153423410>
# 209 : conv2d_251, <keras.layers.convolutional.Conv2D object at 0x153423450>
# 210 : conv2d_256, <keras.layers.convolutional.Conv2D object at 0x153423550>
# 211 : batch_normalization_251, <keras.layers.normalization.BatchNormalization object at 0x153423650>
# 212 : batch_normalization_256, <keras.layers.normalization.BatchNormalization object at 0x153423690>
# 213 : activation_251, <keras.layers.core.Activation object at 0x1534237d0>
# 214 : activation_256, <keras.layers.core.Activation object at 0x153423910>
# 215 : average_pooling2d_25, <keras.layers.pooling.AveragePooling2D object at 0x153423950>
# 216 : conv2d_249, <keras.layers.convolutional.Conv2D object at 0x1534239d0>
# 217 : conv2d_252, <keras.layers.convolutional.Conv2D object at 0x153423ad0>
# 218 : conv2d_257, <keras.layers.convolutional.Conv2D object at 0x153423bd0>
# 219 : conv2d_258, <keras.layers.convolutional.Conv2D object at 0x153423cd0>
# 220 : batch_normalization_249, <keras.layers.normalization.BatchNormalization object at 0x153423dd0>
# 221 : batch_normalization_252, <keras.layers.normalization.BatchNormalization object at 0x153423e10>
# 222 : batch_normalization_257, <keras.layers.normalization.BatchNormalization object at 0x153423f50>
# 223 : batch_normalization_258, <keras.layers.normalization.BatchNormalization object at 0x15342b0d0>
# 224 : activation_249, <keras.layers.core.Activation object at 0x15342b210>
# 225 : activation_252, <keras.layers.core.Activation object at 0x15342b350>
# 226 : activation_257, <keras.layers.core.Activation object at 0x15342b390>
# 227 : activation_258, <keras.layers.core.Activation object at 0x15342b3d0>
# 228 : mixed7, <keras.layers.merge.Concatenate object at 0x15342b410>
# 229 : conv2d_261, <keras.layers.convolutional.Conv2D object at 0x15342b450>
# 230 : batch_normalization_261, <keras.layers.normalization.BatchNormalization object at 0x15342b550>
# 231 : activation_261, <keras.layers.core.Activation object at 0x15342b590>
# 232 : conv2d_262, <keras.layers.convolutional.Conv2D object at 0x15342b6d0>
# 233 : batch_normalization_262, <keras.layers.normalization.BatchNormalization object at 0x15342b7d0>
# 234 : activation_262, <keras.layers.core.Activation object at 0x15342b810>
# 235 : conv2d_259, <keras.layers.convolutional.Conv2D object at 0x15342b950>
# 236 : conv2d_263, <keras.layers.convolutional.Conv2D object at 0x15342ba50>
# 237 : batch_normalization_259, <keras.layers.normalization.BatchNormalization object at 0x15342bb50>
# 238 : batch_normalization_263, <keras.layers.normalization.BatchNormalization object at 0x15342bb90>
# 239 : activation_259, <keras.layers.core.Activation object at 0x15342bcd0>
# 240 : activation_263, <keras.layers.core.Activation object at 0x15342be10>
# 241 : conv2d_260, <keras.layers.convolutional.Conv2D object at 0x15342be50>
# 242 : conv2d_264, <keras.layers.convolutional.Conv2D object at 0x15342bf50>
# 243 : batch_normalization_260, <keras.layers.normalization.BatchNormalization object at 0x153435090>
# 244 : batch_normalization_264, <keras.layers.normalization.BatchNormalization object at 0x1534350d0>
# 245 : activation_260, <keras.layers.core.Activation object at 0x153435210>
# 246 : activation_264, <keras.layers.core.Activation object at 0x153435350>
# 247 : max_pooling2d_12, <keras.layers.pooling.MaxPooling2D object at 0x153435390>
# 248 : mixed8, <keras.layers.merge.Concatenate object at 0x153435410>
# 249 : conv2d_269, <keras.layers.convolutional.Conv2D object at 0x153435450>
# 250 : batch_normalization_269, <keras.layers.normalization.BatchNormalization object at 0x153435550>
# 251 : activation_269, <keras.layers.core.Activation object at 0x153435590>
# 252 : conv2d_266, <keras.layers.convolutional.Conv2D object at 0x1534356d0>
# 253 : conv2d_270, <keras.layers.convolutional.Conv2D object at 0x1534357d0>
# 254 : batch_normalization_266, <keras.layers.normalization.BatchNormalization object at 0x1534358d0>
# 255 : batch_normalization_270, <keras.layers.normalization.BatchNormalization object at 0x153435910>
# 256 : activation_266, <keras.layers.core.Activation object at 0x153435a50>
# 257 : activation_270, <keras.layers.core.Activation object at 0x153435b90>
# 258 : conv2d_267, <keras.layers.convolutional.Conv2D object at 0x153435bd0>
# 259 : conv2d_268, <keras.layers.convolutional.Conv2D object at 0x153435cd0>
# 260 : conv2d_271, <keras.layers.convolutional.Conv2D object at 0x153435dd0>
# 261 : conv2d_272, <keras.layers.convolutional.Conv2D object at 0x153435ed0>
# 262 : average_pooling2d_26, <keras.layers.pooling.AveragePooling2D object at 0x153435fd0>
# 263 : conv2d_265, <keras.layers.convolutional.Conv2D object at 0x15343f090>
# 264 : batch_normalization_267, <keras.layers.normalization.BatchNormalization object at 0x15343f190>
# 265 : batch_normalization_268, <keras.layers.normalization.BatchNormalization object at 0x15343f1d0>
# 266 : batch_normalization_271, <keras.layers.normalization.BatchNormalization object at 0x15343f310>
# 267 : batch_normalization_272, <keras.layers.normalization.BatchNormalization object at 0x15343f450>
# 268 : conv2d_273, <keras.layers.convolutional.Conv2D object at 0x15343f590>
# 269 : batch_normalization_265, <keras.layers.normalization.BatchNormalization object at 0x15343f790>
# 270 : activation_267, <keras.layers.core.Activation object at 0x15343f7d0>
# 271 : activation_268, <keras.layers.core.Activation object at 0x15343f910>
# 272 : activation_271, <keras.layers.core.Activation object at 0x15343f950>
# 273 : activation_272, <keras.layers.core.Activation object at 0x15343f990>
# 274 : batch_normalization_273, <keras.layers.normalization.BatchNormalization object at 0x15343f9d0>
# 275 : activation_265, <keras.layers.core.Activation object at 0x15343fa10>
# 276 : mixed9_0, <keras.layers.merge.Concatenate object at 0x15343fb50>
# 277 : concatenate_5, <keras.layers.merge.Concatenate object at 0x15343fb90>
# 278 : activation_273, <keras.layers.core.Activation object at 0x15343fbd0>
# 279 : mixed9, <keras.layers.merge.Concatenate object at 0x15343fc10>
# 280 : conv2d_278, <keras.layers.convolutional.Conv2D object at 0x15343fc50>
# 281 : batch_normalization_278, <keras.layers.normalization.BatchNormalization object at 0x15343fd50>
# 282 : activation_278, <keras.layers.core.Activation object at 0x15343fd90>
# 283 : conv2d_275, <keras.layers.convolutional.Conv2D object at 0x15343fed0>
# 284 : conv2d_279, <keras.layers.convolutional.Conv2D object at 0x15343ffd0>
# 285 : batch_normalization_275, <keras.layers.normalization.BatchNormalization object at 0x153447110>
# 286 : batch_normalization_279, <keras.layers.normalization.BatchNormalization object at 0x153447150>
# 287 : activation_275, <keras.layers.core.Activation object at 0x153447290>
# 288 : activation_279, <keras.layers.core.Activation object at 0x1534473d0>
# 289 : conv2d_276, <keras.layers.convolutional.Conv2D object at 0x153447410>
# 290 : conv2d_277, <keras.layers.convolutional.Conv2D object at 0x153447510>
# 291 : conv2d_280, <keras.layers.convolutional.Conv2D object at 0x153447610>
# 292 : conv2d_281, <keras.layers.convolutional.Conv2D object at 0x153447710>
# 293 : average_pooling2d_27, <keras.layers.pooling.AveragePooling2D object at 0x153447810>
# 294 : conv2d_274, <keras.layers.convolutional.Conv2D object at 0x153447890>
# 295 : batch_normalization_276, <keras.layers.normalization.BatchNormalization object at 0x153447990>
# 296 : batch_normalization_277, <keras.layers.normalization.BatchNormalization object at 0x1534479d0>
# 297 : batch_normalization_280, <keras.layers.normalization.BatchNormalization object at 0x153447b10>
# 298 : batch_normalization_281, <keras.layers.normalization.BatchNormalization object at 0x153447c50>
# 299 : conv2d_282, <keras.layers.convolutional.Conv2D object at 0x153447d90>
# 300 : batch_normalization_274, <keras.layers.normalization.BatchNormalization object at 0x153447f90>
# 301 : activation_276, <keras.layers.core.Activation object at 0x153447fd0>
# 302 : activation_277, <keras.layers.core.Activation object at 0x153450150>
# 303 : activation_280, <keras.layers.core.Activation object at 0x153450190>
# 304 : activation_281, <keras.layers.core.Activation object at 0x1534501d0>
# 305 : batch_normalization_282, <keras.layers.normalization.BatchNormalization object at 0x153450210>
# 306 : activation_274, <keras.layers.core.Activation object at 0x153450250>
# 307 : mixed9_1, <keras.layers.merge.Concatenate object at 0x153450390>
# 308 : concatenate_6, <keras.layers.merge.Concatenate object at 0x1534503d0>
# 309 : activation_282, <keras.layers.core.Activation object at 0x153450410>
# 310 : mixed10, <keras.layers.merge.Concatenate object at 0x153450450>
# 311 : global_average_pooling2d_3, <keras.layers.pooling.GlobalAveragePooling2D object at 0x153450490>
# 312 : dense_6, <keras.layers.core.Dense object at 0x153450510>
# 313 : dense_6__activation__, <keras.layers.core.Activation object at 0x158d5ef50>
# 314 : dense_7, <keras.layers.core.Dense object at 0x153450610>
# 315 : dense_7__activation__, <keras.layers.core.Activation object at 0x16043bd90>
# 316 : dense_8, <keras.layers.core.Dense object at 0x153450710>
# 317 : dense_8__activation__, <keras.layers.core.Activation object at 0x1604666d0>
