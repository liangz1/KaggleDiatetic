# %%
import keras
from keras.models import Model
from keras.applications.inception_v3 import InceptionV3
from keras.layers import Dense, GlobalAveragePooling2D, Input
import tensorflow as tf
import coremltools
from keras.models import load_model

input_tensor = Input(shape=(224, 224, 3))
base_model = InceptionV3(input_tensor=input_tensor, weights='imagenet', include_top=False)
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(50, activation='relu')(x)
# x = Dropout(0.5)(x)
x = Dense(50, activation='relu')(x)
# x = Dropout(0.5)(x)
output_dim = 2
predictions = Dense(output_dim, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=predictions)
model.load_weights('inception_v3_50_50_13_best_f1.h5')

core_ml=coremltools.converters.keras.convert(model, \
                                             input_names='image', \
                                             output_names='classLabelProbs', \
                                             image_input_names='image', \
                                             class_labels=['negative','positive'], \
                                             predicted_feature_name='classLabel', \
                                             is_bgr=True)
core_ml.save('coreml_model.mlmodel')
# Out:
# 0 : input_8, <keras.engine.input_layer.InputLayer object at 0x196f2e050>
# 1 : conv2d_659, <keras.layers.convolutional.Conv2D object at 0x196f2ecd0>
# 2 : batch_normalization_659, <keras.layers.normalization.BatchNormalization object at 0x196f2e850>
# 3 : activation_680, <keras.layers.core.Activation object at 0x17ca0d090>
# 4 : conv2d_660, <keras.layers.convolutional.Conv2D object at 0x196f2efd0>
# 5 : batch_normalization_660, <keras.layers.normalization.BatchNormalization object at 0x196f2e9d0>
# 6 : activation_681, <keras.layers.core.Activation object at 0x1883fde10>
# 7 : conv2d_661, <keras.layers.convolutional.Conv2D object at 0x13ed20ed0>
# 8 : batch_normalization_661, <keras.layers.normalization.BatchNormalization object at 0x13ed41490>
# 9 : activation_682, <keras.layers.core.Activation object at 0x13ed41290>
# 10 : max_pooling2d_29, <keras.layers.pooling.MaxPooling2D object at 0x14be18d10>
# 11 : conv2d_662, <keras.layers.convolutional.Conv2D object at 0x14be334d0>
# 12 : batch_normalization_662, <keras.layers.normalization.BatchNormalization object at 0x14bf50b10>
# 13 : activation_683, <keras.layers.core.Activation object at 0x14bf7de50>
# 14 : conv2d_663, <keras.layers.convolutional.Conv2D object at 0x169370d10>
# 15 : batch_normalization_663, <keras.layers.normalization.BatchNormalization object at 0x14c0f3290>
# 16 : activation_684, <keras.layers.core.Activation object at 0x14c114190>
# 17 : max_pooling2d_30, <keras.layers.pooling.MaxPooling2D object at 0x1693521d0>
# 18 : conv2d_667, <keras.layers.convolutional.Conv2D object at 0x17a272210>
# 19 : batch_normalization_667, <keras.layers.normalization.BatchNormalization object at 0x17a319690>
# 20 : activation_688, <keras.layers.core.Activation object at 0x17a3192d0>
# 21 : conv2d_665, <keras.layers.convolutional.Conv2D object at 0x17a133a50>
# 22 : conv2d_668, <keras.layers.convolutional.Conv2D object at 0x17a3d1ed0>
# 23 : batch_normalization_665, <keras.layers.normalization.BatchNormalization object at 0x17a156e50>
# 24 : batch_normalization_668, <keras.layers.normalization.BatchNormalization object at 0x17a3f69d0>
# 25 : activation_686, <keras.layers.core.Activation object at 0x17a156a90>
# 26 : activation_689, <keras.layers.core.Activation object at 0x17a3f6610>
# 27 : average_pooling2d_64, <keras.layers.pooling.AveragePooling2D object at 0x17a9f7750>
# 28 : conv2d_664, <keras.layers.convolutional.Conv2D object at 0x1693bdd90>
# 29 : conv2d_666, <keras.layers.convolutional.Conv2D object at 0x17a1e7a10>
# 30 : conv2d_669, <keras.layers.convolutional.Conv2D object at 0x17a4a7750>
# 31 : conv2d_670, <keras.layers.convolutional.Conv2D object at 0x17aa0f490>
# 32 : batch_normalization_664, <keras.layers.normalization.BatchNormalization object at 0x17a0fde10>
# 33 : batch_normalization_666, <keras.layers.normalization.BatchNormalization object at 0x17a2411d0>
# 34 : batch_normalization_669, <keras.layers.normalization.BatchNormalization object at 0x17a94af10>
# 35 : batch_normalization_670, <keras.layers.normalization.BatchNormalization object at 0x17aa4df10>
# 36 : activation_685, <keras.layers.core.Activation object at 0x1693fa810>
# 37 : activation_687, <keras.layers.core.Activation object at 0x17a241550>
# 38 : activation_690, <keras.layers.core.Activation object at 0x17a94aad0>
# 39 : activation_691, <keras.layers.core.Activation object at 0x17aa62890>
# 40 : mixed0, <keras.layers.merge.Concatenate object at 0x17aaeadd0>
# 41 : conv2d_674, <keras.layers.convolutional.Conv2D object at 0x17ae4ae10>
# 42 : batch_normalization_674, <keras.layers.normalization.BatchNormalization object at 0x17ae71ad0>
# 43 : activation_695, <keras.layers.core.Activation object at 0x17ae71710>
# 44 : conv2d_672, <keras.layers.convolutional.Conv2D object at 0x17abc2f10>
# 45 : conv2d_675, <keras.layers.convolutional.Conv2D object at 0x17af232d0>
# 46 : batch_normalization_672, <keras.layers.normalization.BatchNormalization object at 0x17abfb2d0>
# 47 : batch_normalization_675, <keras.layers.normalization.BatchNormalization object at 0x17af4ce10>
# 48 : activation_693, <keras.layers.core.Activation object at 0x17abfb0d0>
# 49 : activation_696, <keras.layers.core.Activation object at 0x17af4ca50>
# 50 : average_pooling2d_65, <keras.layers.pooling.AveragePooling2D object at 0x17b14d350>
# 51 : conv2d_671, <keras.layers.convolutional.Conv2D object at 0x17aaea810>
# 52 : conv2d_673, <keras.layers.convolutional.Conv2D object at 0x17ac93a90>
# 53 : conv2d_676, <keras.layers.convolutional.Conv2D object at 0x17b0616d0>
# 54 : conv2d_677, <keras.layers.convolutional.Conv2D object at 0x17b133b90>
# 55 : batch_normalization_671, <keras.layers.normalization.BatchNormalization object at 0x17ab0e6d0>
# 56 : batch_normalization_673, <keras.layers.normalization.BatchNormalization object at 0x17ad3f610>
# 57 : batch_normalization_676, <keras.layers.normalization.BatchNormalization object at 0x17b098310>
# 58 : batch_normalization_677, <keras.layers.normalization.BatchNormalization object at 0x17b189f10>
# 59 : activation_692, <keras.layers.core.Activation object at 0x17ab39f50>
# 60 : activation_694, <keras.layers.core.Activation object at 0x17ad3f250>
# 61 : activation_697, <keras.layers.core.Activation object at 0x17b098110>
# 62 : activation_698, <keras.layers.core.Activation object at 0x17b19f950>
# 63 : mixed1, <keras.layers.merge.Concatenate object at 0x17b225b90>
# 64 : conv2d_681, <keras.layers.convolutional.Conv2D object at 0x17bf83310>
# 65 : batch_normalization_681, <keras.layers.normalization.BatchNormalization object at 0x17bfa7f10>
# 66 : activation_702, <keras.layers.core.Activation object at 0x17bfa7d10>
# 67 : conv2d_679, <keras.layers.convolutional.Conv2D object at 0x17b52aa50>
# 68 : conv2d_682, <keras.layers.convolutional.Conv2D object at 0x17c03aad0>
# 69 : batch_normalization_679, <keras.layers.normalization.BatchNormalization object at 0x17b54b710>
# 70 : batch_normalization_682, <keras.layers.normalization.BatchNormalization object at 0x17c094290>
# 71 : activation_700, <keras.layers.core.Activation object at 0x17b54b350>
# 72 : activation_703, <keras.layers.core.Activation object at 0x17c094090>
# 73 : average_pooling2d_66, <keras.layers.pooling.AveragePooling2D object at 0x17c492f50>
# 74 : conv2d_678, <keras.layers.convolutional.Conv2D object at 0x17b225c90>
# 75 : conv2d_680, <keras.layers.convolutional.Conv2D object at 0x17b602f50>
# 76 : conv2d_683, <keras.layers.convolutional.Conv2D object at 0x17c0c32d0>
# 77 : conv2d_684, <keras.layers.convolutional.Conv2D object at 0x17c4924d0>
# 78 : batch_normalization_678, <keras.layers.normalization.BatchNormalization object at 0x17b4c1b10>
# 79 : batch_normalization_680, <keras.layers.normalization.BatchNormalization object at 0x17b628a50>
# 80 : batch_normalization_683, <keras.layers.normalization.BatchNormalization object at 0x17c16a750>
# 81 : batch_normalization_684, <keras.layers.normalization.BatchNormalization object at 0x17c4e1c50>
# 82 : activation_699, <keras.layers.core.Activation object at 0x17b24bb10>
# 83 : activation_701, <keras.layers.core.Activation object at 0x17b628690>
# 84 : activation_704, <keras.layers.core.Activation object at 0x17c16a390>
# 85 : activation_705, <keras.layers.core.Activation object at 0x17c4f63d0>
# 86 : mixed2, <keras.layers.merge.Concatenate object at 0x17c569dd0>
# 87 : conv2d_686, <keras.layers.convolutional.Conv2D object at 0x17c654e90>
# 88 : batch_normalization_686, <keras.layers.normalization.BatchNormalization object at 0x17c67ab50>
# 89 : activation_707, <keras.layers.core.Activation object at 0x17c67a790>
# 90 : conv2d_687, <keras.layers.convolutional.Conv2D object at 0x17c725350>
# 91 : batch_normalization_687, <keras.layers.normalization.BatchNormalization object at 0x17c74bf10>
# 92 : activation_708, <keras.layers.core.Activation object at 0x17c74bad0>
# 93 : conv2d_685, <keras.layers.convolutional.Conv2D object at 0x17c569850>
# 94 : conv2d_688, <keras.layers.convolutional.Conv2D object at 0x17cc85750>
# 95 : batch_normalization_685, <keras.layers.normalization.BatchNormalization object at 0x17c5a1350>
# 96 : batch_normalization_688, <keras.layers.normalization.BatchNormalization object at 0x17ccc4390>
# 97 : activation_706, <keras.layers.core.Activation object at 0x17c61db90>
# 98 : activation_709, <keras.layers.core.Activation object at 0x17ccc4190>
# 99 : max_pooling2d_31, <keras.layers.pooling.MaxPooling2D object at 0x17cec0850>
# 100 : mixed3, <keras.layers.merge.Concatenate object at 0x17ce17c10>
# 101 : conv2d_693, <keras.layers.convolutional.Conv2D object at 0x17d31d790>
# 102 : batch_normalization_693, <keras.layers.normalization.BatchNormalization object at 0x17d343ed0>
# 103 : activation_714, <keras.layers.core.Activation object at 0x17d343b10>
# 104 : conv2d_694, <keras.layers.convolutional.Conv2D object at 0x17d3d4a90>
# 105 : batch_normalization_694, <keras.layers.normalization.BatchNormalization object at 0x17d42c250>
# 106 : activation_715, <keras.layers.core.Activation object at 0x17d42c090>
# 107 : conv2d_690, <keras.layers.convolutional.Conv2D object at 0x17cf0de90>
# 108 : conv2d_695, <keras.layers.convolutional.Conv2D object at 0x17d45e290>
# 109 : batch_normalization_690, <keras.layers.normalization.BatchNormalization object at 0x17cf42210>
# 110 : batch_normalization_695, <keras.layers.normalization.BatchNormalization object at 0x17d507710>
# 111 : activation_711, <keras.layers.core.Activation object at 0x17cf42590>
# 112 : activation_716, <keras.layers.core.Activation object at 0x17d507350>
# 113 : conv2d_691, <keras.layers.convolutional.Conv2D object at 0x17cfdf9d0>
# 114 : conv2d_696, <keras.layers.convolutional.Conv2D object at 0x17d5bff10>
# 115 : batch_normalization_691, <keras.layers.normalization.BatchNormalization object at 0x17d01c550>
# 116 : batch_normalization_696, <keras.layers.normalization.BatchNormalization object at 0x17d5e4b50>
# 117 : activation_712, <keras.layers.core.Activation object at 0x17d01c050>
# 118 : activation_717, <keras.layers.core.Activation object at 0x17d6a9090>
# 119 : average_pooling2d_67, <keras.layers.pooling.AveragePooling2D object at 0x17da6e410>
# 120 : conv2d_689, <keras.layers.convolutional.Conv2D object at 0x17ce303d0>
# 121 : conv2d_692, <keras.layers.convolutional.Conv2D object at 0x17d0d2f10>
# 122 : conv2d_697, <keras.layers.convolutional.Conv2D object at 0x17daac350>
# 123 : conv2d_698, <keras.layers.convolutional.Conv2D object at 0x17dadbe10>
# 124 : batch_normalization_689, <keras.layers.normalization.BatchNormalization object at 0x17ce81590>
# 125 : batch_normalization_692, <keras.layers.normalization.BatchNormalization object at 0x17d0f4a10>
# 126 : batch_normalization_697, <keras.layers.normalization.BatchNormalization object at 0x17da1f1d0>
# 127 : batch_normalization_698, <keras.layers.normalization.BatchNormalization object at 0x17db2dcd0>
# 128 : activation_710, <keras.layers.core.Activation object at 0x17ce81b90>
# 129 : activation_713, <keras.layers.core.Activation object at 0x17d0f4650>
# 130 : activation_718, <keras.layers.core.Activation object at 0x17da3e0d0>
# 131 : activation_719, <keras.layers.core.Activation object at 0x17db42a90>
# 132 : mixed4, <keras.layers.merge.Concatenate object at 0x17dbccfd0>
# 133 : conv2d_703, <keras.layers.convolutional.Conv2D object at 0x17df435d0>
# 134 : batch_normalization_703, <keras.layers.normalization.BatchNormalization object at 0x17df7a210>
# 135 : activation_724, <keras.layers.core.Activation object at 0x17df7a590>
# 136 : conv2d_704, <keras.layers.convolutional.Conv2D object at 0x17e0169d0>
# 137 : batch_normalization_704, <keras.layers.normalization.BatchNormalization object at 0x17e051550>
# 138 : activation_725, <keras.layers.core.Activation object at 0x17e051050>
# 139 : conv2d_700, <keras.layers.convolutional.Conv2D object at 0x17dcb7f50>
# 140 : conv2d_705, <keras.layers.convolutional.Conv2D object at 0x17e109f10>
# 141 : batch_normalization_700, <keras.layers.normalization.BatchNormalization object at 0x17dcda510>
# 142 : batch_normalization_705, <keras.layers.normalization.BatchNormalization object at 0x17e12ea10>
# 143 : activation_721, <keras.layers.core.Activation object at 0x17dcda050>
# 144 : activation_726, <keras.layers.core.Activation object at 0x17e12e650>
# 145 : conv2d_701, <keras.layers.convolutional.Conv2D object at 0x17de1d850>
# 146 : conv2d_706, <keras.layers.convolutional.Conv2D object at 0x17e5ed790>
# 147 : batch_normalization_701, <keras.layers.normalization.BatchNormalization object at 0x17dd5ad50>
# 148 : batch_normalization_706, <keras.layers.normalization.BatchNormalization object at 0x17e610ed0>
# 149 : activation_722, <keras.layers.core.Activation object at 0x17ddb4a10>
# 150 : activation_727, <keras.layers.core.Activation object at 0x17e610b10>
# 151 : average_pooling2d_68, <keras.layers.pooling.AveragePooling2D object at 0x17e840890>
# 152 : conv2d_699, <keras.layers.convolutional.Conv2D object at 0x17dbcc950>
# 153 : conv2d_702, <keras.layers.convolutional.Conv2D object at 0x17de6ae10>
# 154 : conv2d_707, <keras.layers.convolutional.Conv2D object at 0x17e6bc790>
# 155 : conv2d_708, <keras.layers.convolutional.Conv2D object at 0x17e7b0150>
# 156 : batch_normalization_699, <keras.layers.normalization.BatchNormalization object at 0x17dc1acd0>
# 157 : batch_normalization_702, <keras.layers.normalization.BatchNormalization object at 0x17de90c90>
# 158 : batch_normalization_707, <keras.layers.normalization.BatchNormalization object at 0x17e6f93d0>
# 159 : batch_normalization_708, <keras.layers.normalization.BatchNormalization object at 0x17e7d3810>
# 160 : activation_720, <keras.layers.core.Activation object at 0x17dc82510>
# 161 : activation_723, <keras.layers.core.Activation object at 0x17decf090>
# 162 : activation_728, <keras.layers.core.Activation object at 0x17e6f91d0>
# 163 : activation_729, <keras.layers.core.Activation object at 0x17e801f10>
# 164 : mixed5, <keras.layers.merge.Concatenate object at 0x17e887cd0>
# 165 : conv2d_713, <keras.layers.convolutional.Conv2D object at 0x17f398490>
# 166 : batch_normalization_713, <keras.layers.normalization.BatchNormalization object at 0x17f4a64d0>
# 167 : activation_734, <keras.layers.core.Activation object at 0x17f4a6110>
# 168 : conv2d_714, <keras.layers.convolutional.Conv2D object at 0x1834dcc90>
# 169 : batch_normalization_714, <keras.layers.normalization.BatchNormalization object at 0x18351d810>
# 170 : activation_735, <keras.layers.core.Activation object at 0x18351d450>
# 171 : conv2d_710, <keras.layers.convolutional.Conv2D object at 0x17e975b10>
# 172 : conv2d_715, <keras.layers.convolutional.Conv2D object at 0x1835d2dd0>
# 173 : batch_normalization_710, <keras.layers.normalization.BatchNormalization object at 0x17e99a7d0>
# 174 : batch_normalization_715, <keras.layers.normalization.BatchNormalization object at 0x1835f9c50>
# 175 : activation_731, <keras.layers.core.Activation object at 0x17e99a410>
# 176 : activation_736, <keras.layers.core.Activation object at 0x183636050>
# 177 : conv2d_711, <keras.layers.convolutional.Conv2D object at 0x17f122c90>
# 178 : conv2d_716, <keras.layers.convolutional.Conv2D object at 0x183965590>
# 179 : batch_normalization_711, <keras.layers.normalization.BatchNormalization object at 0x17f14bb10>
# 180 : batch_normalization_716, <keras.layers.normalization.BatchNormalization object at 0x1856fb1d0>
# 181 : activation_732, <keras.layers.core.Activation object at 0x17f14b750>
# 182 : activation_737, <keras.layers.core.Activation object at 0x1856fb550>
# 183 : average_pooling2d_69, <keras.layers.pooling.AveragePooling2D object at 0x1862d8e90>
# 184 : conv2d_709, <keras.layers.convolutional.Conv2D object at 0x17e89d0d0>
# 185 : conv2d_712, <keras.layers.convolutional.Conv2D object at 0x17f3983d0>
# 186 : conv2d_717, <keras.layers.convolutional.Conv2D object at 0x18572a210>
# 187 : conv2d_718, <keras.layers.convolutional.Conv2D object at 0x1862d8410>
# 188 : batch_normalization_709, <keras.layers.normalization.BatchNormalization object at 0x17e90eb50>
# 189 : batch_normalization_712, <keras.layers.normalization.BatchNormalization object at 0x17f3bcfd0>
# 190 : batch_normalization_717, <keras.layers.normalization.BatchNormalization object at 0x185ef6690>
# 191 : batch_normalization_718, <keras.layers.normalization.BatchNormalization object at 0x186af8dd0>
# 192 : activation_730, <keras.layers.core.Activation object at 0x17e8acd90>
# 193 : activation_733, <keras.layers.core.Activation object at 0x17f3bcdd0>
# 194 : activation_738, <keras.layers.core.Activation object at 0x185ef62d0>
# 195 : activation_739, <keras.layers.core.Activation object at 0x186852cd0>
# 196 : mixed6, <keras.layers.merge.Concatenate object at 0x186b46f90>
# 197 : conv2d_723, <keras.layers.convolutional.Conv2D object at 0x186ea92d0>
# 198 : batch_normalization_723, <keras.layers.normalization.BatchNormalization object at 0x186f51750>
# 199 : activation_744, <keras.layers.core.Activation object at 0x186f51390>
# 200 : conv2d_724, <keras.layers.convolutional.Conv2D object at 0x187008f90>
# 201 : batch_normalization_724, <keras.layers.normalization.BatchNormalization object at 0x18702fa90>
# 202 : activation_745, <keras.layers.core.Activation object at 0x18702f6d0>
# 203 : conv2d_720, <keras.layers.convolutional.Conv2D object at 0x186c30d90>
# 204 : conv2d_725, <keras.layers.convolutional.Conv2D object at 0x1870df350>
# 205 : batch_normalization_720, <keras.layers.normalization.BatchNormalization object at 0x186c56a50>
# 206 : batch_normalization_725, <keras.layers.normalization.BatchNormalization object at 0x187106f50>
# 207 : activation_741, <keras.layers.core.Activation object at 0x186c56690>
# 208 : activation_746, <keras.layers.core.Activation object at 0x187106d50>
# 209 : conv2d_721, <keras.layers.convolutional.Conv2D object at 0x186d09250>
# 210 : conv2d_726, <keras.layers.convolutional.Conv2D object at 0x1871b1810>
# 211 : batch_normalization_721, <keras.layers.normalization.BatchNormalization object at 0x186d30d10>
# 212 : batch_normalization_726, <keras.layers.normalization.BatchNormalization object at 0x1871ee450>
# 213 : activation_742, <keras.layers.core.Activation object at 0x186d71110>
# 214 : activation_747, <keras.layers.core.Activation object at 0x1871ee250>
# 215 : average_pooling2d_70, <keras.layers.pooling.AveragePooling2D object at 0x196d1ced0>
# 216 : conv2d_719, <keras.layers.convolutional.Conv2D object at 0x17dbcca10>
# 217 : conv2d_722, <keras.layers.convolutional.Conv2D object at 0x186e42650>
# 218 : conv2d_727, <keras.layers.convolutional.Conv2D object at 0x187289cd0>
# 219 : conv2d_728, <keras.layers.convolutional.Conv2D object at 0x18737ded0>
# 220 : batch_normalization_719, <keras.layers.normalization.BatchNormalization object at 0x186b92f90>
# 221 : batch_normalization_722, <keras.layers.normalization.BatchNormalization object at 0x186e79290>
# 222 : batch_normalization_727, <keras.layers.normalization.BatchNormalization object at 0x1872c8910>
# 223 : batch_normalization_728, <keras.layers.normalization.BatchNormalization object at 0x196cf58d0>
# 224 : activation_740, <keras.layers.core.Activation object at 0x186b79290>
# 225 : activation_743, <keras.layers.core.Activation object at 0x186e79090>
# 226 : activation_748, <keras.layers.core.Activation object at 0x1872c8550>
# 227 : activation_749, <keras.layers.core.Activation object at 0x185b4a650>
# 228 : mixed7, <keras.layers.merge.Concatenate object at 0x196d52750>
# 229 : conv2d_731, <keras.layers.convolutional.Conv2D object at 0x188348610>
# 230 : batch_normalization_731, <keras.layers.normalization.BatchNormalization object at 0x18837d250>
# 231 : activation_752, <keras.layers.core.Activation object at 0x18837d090>
# 232 : conv2d_732, <keras.layers.convolutional.Conv2D object at 0x188558890>
# 233 : batch_normalization_732, <keras.layers.normalization.BatchNormalization object at 0x188493f50>
# 234 : activation_753, <keras.layers.core.Activation object at 0x1884f28d0>
# 235 : conv2d_729, <keras.layers.convolutional.Conv2D object at 0x18b0b8250>
# 236 : conv2d_733, <keras.layers.convolutional.Conv2D object at 0x1887ae4d0>
# 237 : batch_normalization_729, <keras.layers.normalization.BatchNormalization object at 0x187a84250>
# 238 : batch_normalization_733, <keras.layers.normalization.BatchNormalization object at 0x1887d3cd0>
# 239 : activation_750, <keras.layers.core.Activation object at 0x187b00f50>
# 240 : activation_754, <keras.layers.core.Activation object at 0x188810110>
# 241 : conv2d_730, <keras.layers.convolutional.Conv2D object at 0x187b39f10>
# 242 : conv2d_734, <keras.layers.convolutional.Conv2D object at 0x18911d790>
# 243 : batch_normalization_730, <keras.layers.normalization.BatchNormalization object at 0x187b5eb50>
# 244 : batch_normalization_734, <keras.layers.normalization.BatchNormalization object at 0x1891913d0>
# 245 : activation_751, <keras.layers.core.Activation object at 0x187b9a0d0>
# 246 : activation_755, <keras.layers.core.Activation object at 0x1891911d0>
# 247 : max_pooling2d_32, <keras.layers.pooling.MaxPooling2D object at 0x189248f10>
# 248 : mixed8, <keras.layers.merge.Concatenate object at 0x189248590>
# 249 : conv2d_739, <keras.layers.convolutional.Conv2D object at 0x18958aa90>
# 250 : batch_normalization_739, <keras.layers.normalization.BatchNormalization object at 0x189660ed0>
# 251 : activation_760, <keras.layers.core.Activation object at 0x1895e4090>
# 252 : conv2d_736, <keras.layers.convolutional.Conv2D object at 0x18932d8d0>
# 253 : conv2d_740, <keras.layers.convolutional.Conv2D object at 0x18967bed0>
# 254 : batch_normalization_736, <keras.layers.normalization.BatchNormalization object at 0x18934a590>
# 255 : batch_normalization_740, <keras.layers.normalization.BatchNormalization object at 0x1896bec90>
# 256 : activation_757, <keras.layers.core.Activation object at 0x18934a090>
# 257 : activation_761, <keras.layers.core.Activation object at 0x1896fa0d0>
# 258 : conv2d_737, <keras.layers.convolutional.Conv2D object at 0x1893fcf50>
# 259 : conv2d_738, <keras.layers.convolutional.Conv2D object at 0x18955cdd0>
# 260 : conv2d_741, <keras.layers.convolutional.Conv2D object at 0x189769750>
# 261 : conv2d_742, <keras.layers.convolutional.Conv2D object at 0x189a25d90>
# 262 : average_pooling2d_71, <keras.layers.pooling.AveragePooling2D object at 0x189afa3d0>
# 263 : conv2d_735, <keras.layers.convolutional.Conv2D object at 0x18926c650>
# 264 : batch_normalization_737, <keras.layers.normalization.BatchNormalization object at 0x189421a50>
# 265 : batch_normalization_738, <keras.layers.normalization.BatchNormalization object at 0x1894ed1d0>
# 266 : batch_normalization_741, <keras.layers.normalization.BatchNormalization object at 0x189989390>
# 267 : batch_normalization_742, <keras.layers.normalization.BatchNormalization object at 0x189a629d0>
# 268 : conv2d_743, <keras.layers.convolutional.Conv2D object at 0x189b66c10>
# 269 : batch_normalization_735, <keras.layers.normalization.BatchNormalization object at 0x189296d90>
# 270 : activation_758, <keras.layers.core.Activation object at 0x189421690>
# 271 : activation_759, <keras.layers.core.Activation object at 0x18950d0d0>
# 272 : activation_762, <keras.layers.core.Activation object at 0x189989190>
# 273 : activation_763, <keras.layers.core.Activation object at 0x189a62610>
# 274 : batch_normalization_743, <keras.layers.normalization.BatchNormalization object at 0x189b7b390>
# 275 : activation_756, <keras.layers.core.Activation object at 0x1892f8410>
# 276 : mixed9_0, <keras.layers.merge.Concatenate object at 0x1895a8a10>
# 277 : concatenate_15, <keras.layers.merge.Concatenate object at 0x189b15350>
# 278 : activation_764, <keras.layers.core.Activation object at 0x189bcabd0>
# 279 : mixed9, <keras.layers.merge.Concatenate object at 0x18a942490>
# 280 : conv2d_748, <keras.layers.convolutional.Conv2D object at 0x18eb434d0>
# 281 : batch_normalization_748, <keras.layers.normalization.BatchNormalization object at 0x18eb66410>
# 282 : activation_769, <keras.layers.core.Activation object at 0x18eb958d0>
# 283 : conv2d_745, <keras.layers.convolutional.Conv2D object at 0x18c0c8f10>
# 284 : conv2d_749, <keras.layers.convolutional.Conv2D object at 0x18ec00d50>
# 285 : batch_normalization_745, <keras.layers.normalization.BatchNormalization object at 0x18c0e6410>
# 286 : batch_normalization_749, <keras.layers.normalization.BatchNormalization object at 0x18ec40b10>
# 287 : activation_766, <keras.layers.core.Activation object at 0x18c0e6210>
# 288 : activation_770, <keras.layers.core.Activation object at 0x18ec7c090>
# 289 : conv2d_746, <keras.layers.convolutional.Conv2D object at 0x18c183d50>
# 290 : conv2d_747, <keras.layers.convolutional.Conv2D object at 0x18d28e310>
# 291 : conv2d_750, <keras.layers.convolutional.Conv2D object at 0x19101c5d0>
# 292 : conv2d_751, <keras.layers.convolutional.Conv2D object at 0x1911083d0>
# 293 : average_pooling2d_72, <keras.layers.pooling.AveragePooling2D object at 0x1911c5590>
# 294 : conv2d_744, <keras.layers.convolutional.Conv2D object at 0x18a9427d0>
# 295 : batch_normalization_746, <keras.layers.normalization.BatchNormalization object at 0x18c1c28d0>
# 296 : batch_normalization_747, <keras.layers.normalization.BatchNormalization object at 0x18d2b2f10>
# 297 : batch_normalization_750, <keras.layers.normalization.BatchNormalization object at 0x191053210>
# 298 : batch_normalization_751, <keras.layers.normalization.BatchNormalization object at 0x19112c850>
# 299 : conv2d_752, <keras.layers.convolutional.Conv2D object at 0x191207c90>
# 300 : batch_normalization_744, <keras.layers.normalization.BatchNormalization object at 0x18a968690>
# 301 : activation_767, <keras.layers.core.Activation object at 0x18c1c2510>
# 302 : activation_768, <keras.layers.core.Activation object at 0x18d2b2d10>
# 303 : activation_771, <keras.layers.core.Activation object at 0x191053590>
# 304 : activation_772, <keras.layers.core.Activation object at 0x19112c490>
# 305 : batch_normalization_752, <keras.layers.normalization.BatchNormalization object at 0x191244210>
# 306 : activation_765, <keras.layers.core.Activation object at 0x18a991f50>
# 307 : mixed9_1, <keras.layers.merge.Concatenate object at 0x18eb0bc50>
# 308 : concatenate_16, <keras.layers.merge.Concatenate object at 0x1911dedd0>
# 309 : activation_773, <keras.layers.core.Activation object at 0x191292a50>
# 310 : mixed10, <keras.layers.merge.Concatenate object at 0x1912c8310>
# 311 : global_average_pooling2d_8, <keras.layers.pooling.GlobalAveragePooling2D object at 0x1912c8c10>
# 312 : dense_22, <keras.layers.core.Dense object at 0x16bc7aa50>
# 313 : dense_22__activation__, <keras.layers.core.Activation object at 0x1a24ad450>
# 314 : dense_23, <keras.layers.core.Dense object at 0x1912ed510>
# 315 : dense_23__activation__, <keras.layers.core.Activation object at 0x1a24b6110>
# 316 : dense_24, <keras.layers.core.Dense object at 0x1a22ac850>
# 317 : dense_24__activation__, <keras.layers.core.Activation object at 0x1a24b6290>
